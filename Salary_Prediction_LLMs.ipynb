# %% [markdown]
# <a href="https://colab.research.google.com/github/jayuan101/Salary-Prediction-LLMs/blob/main/Salary_Prediction_LLMs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
df=pd.read_csv('Salary Data.csv')

# %%
df
# Out:
#       Age  Gender Education Level                      Job Title  \
# 0    32.0    Male      Bachelor's              Software Engineer
# 1    28.0  Female        Master's                   Data Analyst
# 2    45.0    Male             PhD                 Senior Manager
# 3    36.0  Female      Bachelor's                Sales Associate
# 4    52.0    Male        Master's                       Director
# ..    ...     ...             ...                            ...
# 370  35.0  Female      Bachelor's       Senior Marketing Analyst
# 371  43.0    Male        Master's         Director of Operations
# 372  29.0  Female      Bachelor's         Junior Project Manager
# 373  34.0    Male      Bachelor's  Senior Operations Coordinator
# 374  44.0  Female             PhD        Senior Business Analyst
#
#      Years of Experience    Salary
# 0                    5.0   90000.0
# 1                    3.0   65000.0
# 2                   15.0  150000.0
# 3                    7.0   60000.0
# ...

# %%
# to display the first 5 data's
df.head()
# Out:
#     Age  Gender Education Level          Job Title  Years of Experience  \
# 0  32.0    Male      Bachelor's  Software Engineer                  5.0
# 1  28.0  Female        Master's       Data Analyst                  3.0
# 2  45.0    Male             PhD     Senior Manager                 15.0
# 3  36.0  Female      Bachelor's    Sales Associate                  7.0
# 4  52.0    Male        Master's           Director                 20.0
#
#      Salary
# 0   90000.0
# 1   65000.0
# 2  150000.0
# 3   60000.0
# 4  200000.0

# %%
# to display about the total number of rows and columns in the dataset
df.shape
# Out:
# (375, 6)

# %%
# to get detail information about the datset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 375 entries, 0 to 374
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Age                  373 non-null    float64
#  1   Gender               373 non-null    object
#  2   Education Level      373 non-null    object
#  3   Job Title            373 non-null    object
#  4   Years of Experience  373 non-null    float64
#  5   Salary               373 non-null    float64
# dtypes: float64(3), object(3)
# memory usage: 17.7+ KB

# %%
# to know about how may data's are null in the dataframe
df.isnull().sum()
# Out:
# Age                    2
# Gender                 2
# Education Level        2
# Job Title              2
# Years of Experience    2
# Salary                 2
# dtype: int64

# %%
df.describe()
# Out:
#               Age  Years of Experience         Salary
# count  373.000000           373.000000     373.000000
# mean    37.431635            10.030831  100577.345845
# std      7.069073             6.557007   48240.013482
# min     23.000000             0.000000     350.000000
# 25%     31.000000             4.000000   55000.000000
# 50%     36.000000             9.000000   95000.000000
# 75%     44.000000            15.000000  140000.000000
# max     53.000000            25.000000  250000.000000

# %%
# to choose the columns which one will be our Feature and Target
df.columns
# Out:
# Index(['Age', 'Gender', 'Education Level', 'Job Title', 'Years of Experience',
#        'Salary'],
#       dtype='object')

# %%
# dropping all the null values from the dataset
df1 = df.dropna()
df1.isnull().sum()
# Out:
# Age                    0
# Gender                 0
# Education Level        0
# Job Title              0
# Years of Experience    0
# Salary                 0
# dtype: int64

# %%
# Compare transformed source data with target data
validation = df[['Age', 'Job Title']].merge(df1, on=['Age', 'Job Title'], how='outer', indicator=True)

# Identify mismatches
mismatches = validation[validation['_merge'] != 'both']

if mismatches.empty:
    print("ETL transformation is accurate.")
else:
    print("Discrepancies found in ETL transformation:")
    print(mismatches)
# Out:
# Discrepancies found in ETL transformation:
#      Age Job Title Gender Education Level  Years of Experience  Salary  \
# 206  NaN       NaN    NaN             NaN                  NaN     NaN
# 207  NaN       NaN    NaN             NaN                  NaN     NaN
#
#         _merge
# 206  left_only
# 207  left_only

# %%
# Accuracy: Validate transaction amounts against a source system (example assumes a validation function exists)
def validate_amounts(df):
    # Placeholder for validation logic
    return df['Salary'].apply(lambda x: True if x >= 0 else False)

df['amount_valid'] = validate_amounts(df)

# Completeness: Check for missing values
completeness = df.isnull().sum()

# Consistency: Check for unique transaction IDs
consistency = df['Job Title'].is_unique

# Timeliness: Measure ETL process duration (example assumes start and end times are tracked)
import time
start_time = time.time()
# ETL process...
end_time = time.time()
timeliness = end_time - start_time

# Uniqueness: Check for duplicates
duplicates = df.duplicated().sum()

# Log metrics
metrics = {
    'accuracy': df['amount_valid'].mean(),
    'completeness': completeness,
    'consistency': consistency,
    'timeliness': timeliness,
    'uniqueness': duplicates
}

print(metrics)
# Out:
# {'accuracy': 0.9946666666666667, 'completeness': Age                    2
# Gender                 2
# Education Level        2
# Job Title              2
# Years of Experience    2
# Salary                 2
# amount_valid           0
# dtype: int64, 'consistency': False, 'timeliness': 4.5299530029296875e-05, 'uniqueness': 50}

# %%
# Define the chunk size
chunk_size = 1000  # Number of rows per chunk

# Initialize an empty list to collect processed data
processed_data = []

# Iterate over the CSV file in chunks
for chunk in pd.read_csv('Salary Data.csv', chunksize=chunk_size):
    # Perform some processing on each chunk
    # For example, let's say we want to calculate the mean of the 'value' column
    chunk_mean = chunk['Salary'].mean()
    print(f"Chunk mean: {chunk_mean}")

    # Append the processed result to the list
    processed_data.append(chunk_mean)

# After processing all chunks, you can further process the collected data
overall_mean = sum(processed_data) / len(processed_data)
print(f"Overall mean: {overall_mean}")
# Out:
# Chunk mean: 100577.34584450402
# Overall mean: 100577.34584450402

# %%
# Check for missing values
print("Missing values before handling:")
print(df.isnull().sum())

# Fill missing values with a default value
df_filled_default = df.fillna({
    'transaction_id': -1,
    'customer_id': -1,
    'transaction_date': '1970-01-01',
    'amount': 0.0
})

print("Missing values after filling with default values:")
print(df_filled_default.isnull().sum())

# Save the DataFrame with default values to a new CSV file
df_filled_default.to_csv('Salary Data.csv', index=False)

# Fill missing values with the mean of the column (only for numeric columns)
df_filled_mean = df.copy()
df_filled_mean['Salary'].fillna(df['Salary'].mean(), inplace=True)

print("Missing values after filling 'amount' with mean:")
print(df_filled_mean.isnull().sum())

# Save the DataFrame with mean-filled values to a new CSV file
df_filled_mean.to_csv('filled_mean_financial_transactions.csv', index=False)

print("Missing values handled and data saved to respective files.")
# Out:
# Missing values before handling:
# Age                    2
# Gender                 2
# Education Level        2
# Job Title              2
# Years of Experience    2
# Salary                 2
# amount_valid           0
# dtype: int64
# Missing values after filling with default values:
# Age                    2
# Gender                 2
# Education Level        2
# Job Title              2
# Years of Experience    2
# Salary                 2
# amount_valid           0
# dtype: int64
# Missing values after filling 'amount' with mean:
# Age                    2
# Gender                 2
# Education Level        2
# Job Title              2
# Years of Experience    2
# Salary                 0
# amount_valid           0
# dtype: int64
# Missing values handled and data saved to respective files.

# %%
# Converting the Categorial data into numbers
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
df1['Education Level'] = label_encoder.fit_transform(df1['Education Level'])
df1.head()
# Out:
# <ipython-input-45-c8f7d5715209>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Education Level'] = label_encoder.fit_transform(df1['Education Level'])
#     Age  Gender  Education Level          Job Title  Years of Experience  \
# 0  32.0    Male                0  Software Engineer                  5.0
# 1  28.0  Female                1       Data Analyst                  3.0
# 2  45.0    Male                2     Senior Manager                 15.0
# 3  36.0  Female                0    Sales Associate                  7.0
# 4  52.0    Male                1           Director                 20.0
#
#      Salary
# 0   90000.0
# 1   65000.0
# 2  150000.0
# 3   60000.0
# 4  200000.0

# %%
# Splitting the data into x and y for training and testing purpose
x=df1[['Education Level', 'Years of Experience']]
x.shape
# Out:
# (373, 2)

# %%
x.head(5)
# Out:
#    Education Level  Years of Experience
# 0                0                  5.0
# 1                1                  3.0
# 2                2                 15.0
# 3                0                  7.0
# 4                1                 20.0

# %%
y=df1[['Salary']]
y.head(5)
# Out:
#      Salary
# 0   90000.0
# 1   65000.0
# 2  150000.0
# 3   60000.0
# 4  200000.0

# %%
# Splitting the above data into training and testing data
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size= 0.2,random_state = 9598)

# %%
# to know about the shape of traing and testing data

print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (298, 2)
# (75, 2)
# (298, 1)
# (75, 1)

# %%
# As it is the Regrssion Problem lets try all the Regression Algorith to get the best accuracy
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
# To train and fit the model
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
# to predict the data
y_pred = model.predict(x_test)
y_pred
# Out:
# array([[130293.72312675],
#        [183733.0198562 ],
#        [ 69249.9165435 ],
#        [ 45499.11799708],
#        [116751.51363635],
#        [ 94667.52530712],
#        [137898.23298055],
#        [ 57374.51727029],
#        [142169.12239996],
#        [ 57374.51727029],
#        [ 51436.81763369],
#        [ 75187.61618011],
#        [100605.22494372],
#        [ 93000.71508993],
#        [126022.83370734],
#        [191337.52971   ],
#        [ 63312.2169069 ],
#        [ 45499.11799708],
#        [159982.22130978],
#        [ 33623.71872387],
#        [ 45499.11799708],
#        [ 76854.4263973 ],
#        [ 45499.11799708],
#        [ 81125.31581672],
#        [149773.63225376],
#        [ 93000.71508993],
#        [149773.63225376],
#        [ 63312.2169069 ],
#        [ 93000.71508993],
#        [ 82792.12603391],
#        [ 63312.2169069 ],
#        [ 88729.82567051],
#        [ 57374.51727029],
#        [ 39561.41836048],
#        [ 51436.81763369],
# ...

# %%
# to know what the orignal prediction was for the testing data
y_test
# Out:
#        Salary
# 74   120000.0
# 60   170000.0
# 89    55000.0
# 22    50000.0
# 343  150000.0
# ..        ...
# 111   95000.0
# 307   50000.0
# 31    55000.0
# 249  170000.0
# 102  150000.0
#
# [75 rows x 1 columns]

# %%
# to Calculate the Accuracy of the Model
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error,mean_squared_error

# %%
# to print the mean absolute error
mean_absolute_error(y_test,y_pred)
# Out:
# 9859.883754159075

# %%
# to print the mean absolute percentage
per_e = mean_absolute_percentage_error(y_test,y_pred)
per_e
# Out:
# 0.10963749345183432

# %%
# to print the accuracy in percentage
acc1 = (1-per_e)*100
acc1
# Out:
# 89.03625065481657

# %%
# Trying other Algorhithms to check which gives the best accuracy

# KNeighbors Regressor

from sklearn.neighbors import KNeighborsRegressor
model2 = KNeighborsRegressor()
model2.fit(x_train,y_train)
y_pred2 = model2.predict(x_test)
error2 = mean_absolute_percentage_error(y_test,y_pred2)
acc2 = (1-error2)*100
acc2
# Out:
# 88.57202238749203

# %%
# DecisionTree Regressor

from sklearn.tree import DecisionTreeRegressor
model3 = DecisionTreeRegressor()
model3.fit(x_train,y_train)
y_pred3 = model3.predict(x_test)
error3 = mean_absolute_percentage_error(y_test,y_pred3)
acc3 = (1-error3)*100
acc3
# Out:
# 89.18331140155195

# %%
# RandomForest Regressor

from sklearn.ensemble import RandomForestRegressor
model4 = RandomForestRegressor()
model4.fit(x_train,y_train)
y_pred4 = model4.predict(x_test)
error4 = mean_absolute_percentage_error(y_test,y_pred4)
acc4 = (1-error4)*100
acc4
# Out:
# <ipython-input-60-8ec4cef206a6>:5: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model4.fit(x_train,y_train)
# 89.19783748097063

# %%
print("The Acuuracy of Linear Regressor is ",acc1)
print("The Acuuracy of KNeighbors Regressor is ",acc2)
print("The Acuuracy of DecisionTree Regressor is ",acc3)
print("The Acuuracy of RandomForest Regressor is ",acc4)
# Out:
# The Acuuracy of Linear Regressor is  89.03625065481657
# The Acuuracy of KNeighbors Regressor is  88.57202238749203
# The Acuuracy of DecisionTree Regressor is  89.18331140155195
# The Acuuracy of RandomForest Regressor is  89.19783748097063
